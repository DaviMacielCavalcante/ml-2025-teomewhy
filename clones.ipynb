# %%
import pandas as pd
from sklearn import tree
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet("data/dados_clones.parquet")
df.head()
# Out:
#    p2o_master_id  Massa(em kilos) General Jedi encarregado  Estatura(cm)  \
# 0       10578986            83.13                     Yoda        180.25
# 1       10976676            83.08                     Yoda        180.39
# 2       10588329            83.12                 Shaak Ti        180.26
# 3       10254411            83.38                 Shaak Ti        180.35
# 4       10634458            83.15                 Shaak Ti        180.31
#
#   Distância Ombro a ombro Tamanho do crânio Tamanho dos pés  \
# 0                  Tipo 4            Tipo 1          Tipo 5
# 1                  Tipo 3            Tipo 2          Tipo 5
# 2                  Tipo 4            Tipo 5          Tipo 5
# 3                  Tipo 2            Tipo 2          Tipo 5
# 4                  Tipo 3            Tipo 2          Tipo 2
#
#    Tempo de existência(em meses)     Status
# 0                            0.0  Defeituoso
# 1                            0.0  Defeituoso
# ...

# %%
df.columns
# Out:
# Index(['p2o_master_id', 'Massa(em kilos)', 'General Jedi encarregado',
#        'Estatura(cm)', 'Distância Ombro a ombro', 'Tamanho do crânio',
#        'Tamanho dos pés', 'Tempo de existência(em meses)', 'Status '],
#       dtype='object')

# %%
standardized_columns = [col.lower().strip().replace(" ", "_") for col in df.columns]

# %%
standardized_columns
# Out:
# ['p2o_master_id',
#  'massa(em_kilos)',
#  'general_jedi_encarregado',
#  'estatura(cm)',
#  'distância_ombro_a_ombro',
#  'tamanho_do_crânio',
#  'tamanho_dos_pés',
#  'tempo_de_existência(em_meses)',
#  'status']

# %%
df.columns = standardized_columns

# %%
model = tree.DecisionTreeClassifier(random_state=42)

y = df['status']

# %%
unsuable_columns = ['status', 'general_jedi_encarregado', 'p2o_master_id']

# %%
features = [col for col in df.columns if col not in unsuable_columns]
X = df[features]
X
# Out:
#          massa(em_kilos)  estatura(cm) distância_ombro_a_ombro  \
# 0                  83.13        180.25                  Tipo 4
# 1                  83.08        180.39                  Tipo 3
# 2                  83.12        180.26                  Tipo 4
# 3                  83.38        180.35                  Tipo 2
# 4                  83.15        180.31                  Tipo 3
# ...                  ...           ...                     ...
# 1048714            84.14        181.03                  Tipo 2
# 1048715            83.10        180.62                  Tipo 2
# 1048716            83.63        180.54                  Tipo 5
# 1048717            83.02        180.06                  Tipo 1
# 1048718            83.92        180.31                  Tipo 5
#
#         tamanho_do_crânio tamanho_dos_pés  tempo_de_existência(em_meses)
# 0                  Tipo 1          Tipo 5                            0.0
# ...

# %%
df["distância_ombro_a_ombro"].unique()
# Out:
# array(['Tipo 4', 'Tipo 3', 'Tipo 2', 'Tipo 1', 'Tipo 5'], dtype=object)

# %%
df["tamanho_do_crânio"].unique()
# Out:
# array(['Tipo 1', 'Tipo 2', 'Tipo 5', 'Tipo 3', 'Tipo 4'], dtype=object)

# %%
df["tamanho_dos_pés"].unique()
# Out:
# array(['Tipo 5', 'Tipo 2', 'Tipo 1', 'Tipo 3', 'Tipo 4'], dtype=object)

# %%
X = X.replace({
    "Tipo 1": 1, "Tipo 2": 2, "Tipo 3": 3, "Tipo 4": 4, "Tipo 5": 5
})
# Out:
# /tmp/ipykernel_345183/2741958515.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.replace({

# %%
model.fit(X=X, y=y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
plt.figure(dpi=400)
tree.plot_tree(
    model, 
    feature_names=features,
    class_names=model.classes_,
    filled=True,
    max_depth=3)

plt.show()
